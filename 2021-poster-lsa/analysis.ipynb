# %% [markdown]
# # Title of poster
#
# *Stefan Pophristic & Kathryn Schuler; poster presented at the 2021 LSA annual meeting*
#
# - [link to poster](add-when-complete)
# - [link to short video intro](add-when-complete)

# %%
# install packages 
#install.packages('tidyjson')

#then load what we need
options(tidyverse.quiet = TRUE) # load tidyverse but be quiet about it
library(tidyverse)
library(tidyjson)
library(knitr)

# %%
# get our data
rawdata <- read.csv('2021-poster-lsa/2020-12-22-exp16-data.csv') %>%
    filter(data != "", !(participant %in% c(0, "5cc08aa4d923cf0016ea55a5"))) # filter out our testers

data <- rawdata %>%
    as.tbl_json(json.column="data") %>% gather_array %>% spread_all %>%
    enter_object(answers) %>% # handle the cloze answers
    mutate(answers = ..JSON)

surveydata <- rawdata %>%
    as.tbl_json(json.column="data") %>% gather_array %>% spread_all

# %%
responses <- data %>% 
    mutate(is_novel = ifelse(correct_answer == "none", 1, 0)) %>%
    mutate(is_correct = ifelse(correct_answer == answers, 1, 0)) %>%
    group_by(random_id, is_novel, image, sentence) %>%
    summarise(n = n(), answer = unlist(unique(answers)))

responses %>% head()
# Out:
# `summarise()` regrouping output by 'random_id', 'is_novel', 'image' (override with `.groups` argument)
#   random_id    is_novel image
# 1 3gjn0frayvcu 0        cat
# 2 3gjn0frayvcu 0        cat
# 3 3gjn0frayvcu 0        cat_ball
# 4 3gjn0frayvcu 0        duckling
# 5 3gjn0frayvcu 0        duckling_ball
# 6 3gjn0frayvcu 0        egg
#   sentence
# 1 <p>Ovo je moja mačka.</p><p>Mačka hoće moju loptu. </p><p>Ja hoću loptu.</p><p>Kojoj životinji ću dati loptu?</p><p>Ja ću dati loptu %mački%.</p>
# 2 <p>Ovo je moja mačka.</p><p>Teta hoće ovu životinju.</p><p>Koju životinju hoće teta?</p><p>Teta hoće %mačku%.</p>
# 3 <p>Ovo je moja mačka.</p><p>Mačka ima loptu.</p><p>Ja hoću loptu.</p><p>Od koje životinje ću uzeti loptu?</p><p>Ja ću uzeti loptu od %mačke%.</p>
# 4 <p>Ovo je moje pače.</p><p>Pače hoće moju loptu. </p><p>Ja hoću loptu.</p><p>Kojoj životinji ću dati loptu?</p><p>Ja ću dati loptu %pačetu%.</p>
# 5 <p>Ovo je moje pače.</p><p>Pače ima loptu.</p><p>Ja hoću loptu.</p><p>Od koje životinje ću uzeti loptu?</p><p>Ja ću uzeti loptu od %pačeta%.</p>
# 6 <p>Ovo je jaje.</p><p>Čije je ovo?</p><p>Jaje je %moje%.</p>
#   n answer
# 1 1 mački
# 2 1 mačku
# 3 1 mačke
# 4 1 pačetu
# 5 1 pačeta
# 6 1 moje

# %%
testblocks <- data.frame(
        image = c("monster_1", "monster_2"
                  , "monster_3", "monster_4", "monster_5", "monster_6"
                  , "monster_7", "monster_8", "monster_9", "monster_10"
                  , "object_1", "object_2", "object_3", "object_4")
        , block = c("accusative", "accusative"
               , "genative", "genative", "genative", "genative"
               , "dative", "dative", "dative", "dative"
               , "gender", "gender", "gender", "gender")
        , prompt = c("strum", "neska"
                    , "kust", "grasa", "tero", "slume"
                    , "djat", "vruda", "guno", "klune"
                    , "pok", "kiza", "sigo", "meve")
    )

responses <- responses %>% 
    filter(is_novel == 1) %>%
    left_join(testblocks, by = "image")

# %%
options(repr.plot.width = 8, repr.plot.height = 5)

library(forcats)

ggplot(filter(responses, is_novel == 1, block == "accusative")) +
    facet_grid( ~ prompt, scales = "free") +
    geom_bar(mapping = aes(x=fct_infreq(answer))) +
    theme_classic(base_size = 20) +
    theme(axis.text.x=element_text(angle = -90, hjust = 0)) +
    theme(legend.position = "None") +
    labs(title = "Accusative", x = "wug test response")

ggplot(filter(responses, is_novel == 1, block == "genative")) +
    facet_grid( ~ prompt, scales = "free") +
    geom_bar(mapping = aes(x=fct_infreq(answer))) +
    theme_classic(base_size = 20) +
    theme(axis.text.x=element_text(angle = -90, hjust = 0)) +
    theme(legend.position = "None") +
    labs(title = "Genative", x = "wug test response")

ggplot(filter(responses, is_novel == 1, block == "dative")) +
    facet_grid( ~ prompt, scales = "free") +
    geom_bar(mapping = aes(x=fct_infreq(answer))) +
    theme_classic(base_size = 20) +
    theme(axis.text.x=element_text(angle = -90, hjust = 0)) +
    theme(legend.position = "None") +
    labs(title = "Dative", x = "wug test response")

ggplot(filter(responses, is_novel == 1, block == "gender")) +
    facet_grid( ~ prompt, scales = "free") +
    geom_bar(mapping = aes(x=fct_infreq(answer))) +
    theme_classic(base_size = 20) +
    theme(axis.text.x=element_text(angle = -90, hjust = 0)) +
    theme(legend.position = "None") +
    labs(title = "Gender", x = "wug test response")
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
surveydata %>% filter(trial_type == 'survey-text') %>%
    select(random_id, responses)
# Out:
#    random_id
# 1  tu14nguolemf
# 2  4y3ryvudfkem
# 3  w8en5a82br1q
# 4  9hc4ulkph704
# 5  r3jyk97claex
# 6  3gjn0frayvcu
# 7  rqcq3q09hwxx
# 8  ouyw5zy6j4rn
# 9  uxu67o5l6nld
# 10 fr5aeg51jl3v
# 11 smw2gr34eff9
# 12 oznhrkpeqx73
# 13 65y8v8rr2bfe
# 14 cjr5t2qd1aqo
# 15 svyq692y5t5m
# 16 9yatv5m5l6fn
# 17 dh9u4fvrzx40
# 18 hoc45rjzbd9w
# 19 zcnz35bspoey
# 20 ukm0c5ua0pn4
#    responses
# 1  {"Q0":"Da","Q1":"","Q2":"Ne, engleski i italianski su bili prvi ","Q3":"Ne, engleski ","Q4":"Holandija  (The Netherlands)","Q5":"Serbian is my mother tongue but we speak italian at home due to my serbian family member speaking fluent italian. Also due to learning english and dutch at school, it has not taken priority. "}
# 2  {"Q0":"Srpski mi je maternji jezik.","Q1":"Srpski znam od rodjenja.","Q2":"Da, srpski i engleski su bili primarni jezici.","Q3":"Da, srpski je bio primarni jezik u skoli.Drugi jezici su bili engleski i nemacki.","Q4":"U Srbiji","Q5":"Srpski mi je maternji jezik i imam obimno znanje iz pravopisa i gramatike. \\nEngleski, francuski i nemacki govorim tecno, ali najbolje poznajem englesku gramatiku i pravopis te bih mogao da izdvojim engleski kao drugi maternji jezik."}
# 3  {"Q0":"NE","Q1":"bio sam 10/11 kad sam se naučio bosanki,hrvatski i srpski jezik.","Q2":"NE vsi smo slovenci.","Q3":"Pričali smo po slovenski.","Q4":"Slovenija, Murska Sobota.","Q5":"Ne"}
# 4  {"Q0":"ne","Q1":"6-7","Q2":"ne","Q3":"ne","Q4":"Makedonija","Q5":"ne"}
# 5  {"Q0":"Da, ali sam ga zaista naučila tek oko 11 godine.","Q1":"Nisam ga učila kao strani jezik.","Q2":"I srpski i italijanski su se govorili podjednako, u zavisnosti od teme i situacije.","Q3":"Ne, u školi sam govorila italijanski kao primarni jezik.","Q4":"U Italiji.","Q5":""}
# 6  {"Q0":"nije","Q1":"nisam se aktivno učila","Q2":"ne gorovilo se je samo slovenščina","Q3":"ne. ali učili smo se engleski i njemački","Q4":"Slovenija","Q5":"nisam se jih učila ali smo gledali hrvatski TV, čitala sam hrvatske stripove in svako ljeto smo otišli na hrvatsko."}
# 7  {"Q0":"Da","Q1":"","Q2":"Da, ne nikad.","Q3":"U školi je bio primarni slovenski.","Q4":"Ljubljana Slovenija","Q5":""}
# 8  {"Q0":"Nije","Q1":"10","Q2":"Nije bio, primarni jezik je bio Slovenački/slovenski ali razumijem sve.","Q3":"Nije bio.","Q4":"Slovenija","Q5":"Imam dosta iskustva sa bosanskim/hrvatskim/srpskim jezikom. Kod nas dosta ljudi prića ovaj jezik sluša se muzika na ovom jeziku, čitaju novine, gledaju filmovi."}
# 9  {"Q0":"mislim da jeste","Q1":"-","Q2":"kod kuće pričali smo bosanski i češki 50/50","Q3":"nije, primarni jezik je bio češki jezik","Q4":"Prag, Češka republika","Q5":"odrastao sam u familiji kdjde smo govorili češki i bosanski, ali danas ne govorim puno bosanski i puno sam zaboravio"}
# 10 {"Q0":"Ne","Q1":"23","Q2":"samo su moji baka i deda govorili srpski.","Q3":"Ne, išao sam u grčku školu","Q4":"greece","Q5":""}
# 11 {"Q0":"nije","Q1":"10","Q2":"ne / ne","Q3":"nije / ne","Q4":"Sloveniji","Q5":"gledam hrvatsku i srpsku TV, slušam balkansku glasbu"}
# 12 {"Q0":"Ne","Q1":"15","Q2":"Ne. Kod kuće govorimo slovenački","Q3":"Ne. Slovenački","Q4":"Slovenija, Ljubljana","Q5":"Govorim slovenački, engleski i japanski. Razumijem i hrvatski i srpski"}
# 13 {"Q0":"ne","Q1":"od rodjenja","Q2":"srpski i madjarski su bili primarni jeyici kod kuce","Q3":"Skola je bila srpska, ali je imala madjarsko odelenje","Q4":"Srbija, Novi Sad","Q5":"ne"}
# 14 {"Q0":"Da","Q1":"","Q2":"Jeste, nisu.","Q3":"Jeste, nisu","Q4":"Banja Luka, Bosna i Hercegovina","Q5":""}
# 15 {"Q0":"He","Q1":"","Q2":"","Q3":"","Q4":"Portugal","Q5":""}
# 16 {"Q0":"Da, hrvatski mi je materni jezik","Q1":"","Q2":"Govorilo se talijanksi","Q3":"hrvatski i talijanski","Q4":"u Hrvatskoj","Q5":"Govorim više jezika i moram ih sve prakticirati jer inače nalazim poteškoće u govoru"}
# 17 {"Q0":"jeste","Q1":"","Q2":"1. da\\n2. ne","Q3":"1. da\\n2. ne","Q4":"Banja Luka, Bosna i Hercegovina","Q5":"Veza između prisvojne zamjenice (moj, moja, moje) i imenice u uvodnim rečenicama Vašeg eksperimenta mi je pomogla da odredim rod imenice i tako ga (pravilno) mijenjam kroz padeže."}
# 18 {"Q0":"Ne","Q1":"Da, imala sam oko 12 godina.","Q2":"Ne. Več smo čitali srpske knjige.","Q3":"Ne","Q4":"Slovenia - Novo mesto","Q5":"Srpski jezik naučila sam zbog srpskih pjevača. Jer volim, da slušam ovo muziku i slušam pjevače kad govore o svom životu. I volim srpske youtubere."}
# 19 {"Q0":"NE.","Q1":"10","Q2":"ne, slovenački","Q3":"ne, slovenački","Q4":"U Sloveniji, u Mariboru.","Q5":""}
# 20 {"Q0":"Ne","Q1":"","Q2":"","Q3":"","Q4":"","Q5":""}
#    ..JSON
# 1  164622                                                                                                                                                                                                                                                                                                                            , {"Q0":"Da","Q1":"","Q2":"Ne, engleski i italianski su bili prvi ","Q3":"Ne, engleski ","Q4":"Holandija  (The Netherlands)","Q5":"Serbian is my mother tongue but we speak italian at home due to my serbian family member speaking fluent italian. Also due to learning english and dutch at school, it has not taken priority. "}, survey-text                                                                                                                                                                                                                                                                                                                       , 32                                                                                                                                                                                                                                                                                                                                , 514517                                                                                                                                                                                                                                                                                                                            , 0.0-3.0
# 2  892708.335000003                                                                                                                                                                                                                                                                                                                                                                                                                                                                      , {"Q0":"Srpski mi je maternji jezik.","Q1":"Srpski znam od rodjenja.","Q2":"Da, srpski i engleski su bili primarni jezici.","Q3":"Da, srpski je bio primarni jezik u skoli.Drugi jezici su bili engleski i nemacki.","Q4":"U Srbiji","Q5":"Srpski mi je maternji jezik i imam obimno znanje iz pravopisa i gramatike. \\nEngleski, francuski i nemacki govorim tecno, ali najbolje poznajem englesku gramatiku i pravopis te bih mogao da izdvojim engleski kao drugi maternji jezik."}, survey-text                                                                                                                                                                                                                                                                                                                                                                                                                                                                           , 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    , 1809693                                                                                                                                                                                                                                                                                                                                                                                                                                                                               , 0.0-3.0
# 3  260769.345                                                                                                                                                                                 , {"Q0":"NE","Q1":"bio sam 10/11 kad sam se naučio bosanki,hrvatski i srpski jezik.","Q2":"NE vsi smo slovenci.","Q3":"Pričali smo po slovenski.","Q4":"Slovenija, Murska Sobota.","Q5":"Ne"}, survey-text                                                                                                                                                                                , 32                                                                                                                                                                                         , 804595                                                                                                                                                                                     , 0.0-3.0
# 4  38781                                                                 , {"Q0":"ne","Q1":"6-7","Q2":"ne","Q3":"ne","Q4":"Makedonija","Q5":"ne"}, survey-text                                                           , 32                                                                    , 375611                                                                , 0.0-3.0
# 5  107787                                                                                                                                                                                                                                                                                , {"Q0":"Da, ali sam ga zaista naučila tek oko 11 godine.","Q1":"Nisam ga učila kao strani jezik.","Q2":"I srpski i italijanski su se govorili podjednako, u zavisnosti od teme i situacije.","Q3":"Ne, u školi sam govorila italijanski kao primarni jezik.","Q4":"U Italiji.","Q5":""}, survey-text                                                                                                                                                                                                                                                                           , 32                                                                                                                                                                                                                                                                                    , 284141                                                                                                                                                                                                                                                                                , 0.0-3.0
# 6  147347                                                                                                                                                                                                                                                                           , {"Q0":"nije","Q1":"nisam se aktivno učila","Q2":"ne gorovilo se je samo slovenščina","Q3":"ne. ali učili smo se engleski i njemački","Q4":"Slovenija","Q5":"nisam se jih učila ali smo gledali hrvatski TV, čitala sam hrvatske stripove in svako ljeto smo otišli na hrvatsko."}, survey-text                                                                                                                                                                                                                                                                      , 32                                                                                                                                                                                                                                                                               , 429627                                                                                                                                                                                                                                                                           , 0.0-3.0
# 7  66492.0999999158                                                                                                     , {"Q0":"Da","Q1":"","Q2":"Da, ne nikad.","Q3":"U školi je bio primarni slovenski.","Q4":"Ljubljana Slovenija","Q5":""}, survey-text                                                                                                          , 32                                                                                                                   , 448707                                                                                                               , 0.0-3.0
# 8  159429.600000003                                                                                                                                                                                                                                                                                                , {"Q0":"Nije","Q1":"10","Q2":"Nije bio, primarni jezik je bio Slovenački/slovenski ali razumijem sve.","Q3":"Nije bio.","Q4":"Slovenija","Q5":"Imam dosta iskustva sa bosanskim/hrvatskim/srpskim jezikom. Kod nas dosta ljudi prića ovaj jezik sluša se muzika na ovom jeziku, čitaju novine, gledaju filmovi."}, survey-text                                                                                                                                                                                                                                                                                                     , 32                                                                                                                                                                                                                                                                                                              , 391767                                                                                                                                                                                                                                                                                                          , 0.0-3.0
# 9  186844.324999955                                                                                                                                                                                                                                                                            , {"Q0":"mislim da jeste","Q1":"-","Q2":"kod kuće pričali smo bosanski i češki 50/50","Q3":"nije, primarni jezik je bio češki jezik","Q4":"Prag, Češka republika","Q5":"odrastao sam u familiji kdjde smo govorili češki i bosanski, ali danas ne govorim puno bosanski i puno sam zaboravio"}, survey-text                                                                                                                                                                                                                                                                                 , 32                                                                                                                                                                                                                                                                                          , 480528                                                                                                                                                                                                                                                                                      , 0.0-3.0
# 10 248931.81                                                                                                                     , {"Q0":"Ne","Q1":"23","Q2":"samo su moji baka i deda govorili srpski.","Q3":"Ne, išao sam u grčku školu","Q4":"greece","Q5":""}, survey-text                                                                                                                   , 32                                                                                                                            , 636030                                                                                                                        , 0.0-3.0
# 11 161894                                                                                                                              , {"Q0":"nije","Q1":"10","Q2":"ne / ne","Q3":"nije / ne","Q4":"Sloveniji","Q5":"gledam hrvatsku i srpsku TV, slušam balkansku glasbu"}, survey-text                                                                                                                         , 32                                                                                                                                  , 516485                                                                                                                              , 0.0-3.0
# 12 417089.599999948                                                                                                                                                                             , {"Q0":"Ne","Q1":"15","Q2":"Ne. Kod kuće govorimo slovenački","Q3":"Ne. Slovenački","Q4":"Slovenija, Ljubljana","Q5":"Govorim slovenački, engleski i japanski. Razumijem i hrvatski i srpski"}, survey-text                                                                                                                                                                                  , 32                                                                                                                                                                                           , 873979                                                                                                                                                                                       , 0.0-3.0
# ...
# 15 24839.4900000003                                           , {"Q0":"He","Q1":"","Q2":"","Q3":"","Q4":"Portugal","Q5":""}, survey-text                                                , 32                                                         , 444102                                                     , 0.0-3.0
# 16 310986.144999995                                                                                                                                                                                                           , {"Q0":"Da, hrvatski mi je materni jezik","Q1":"","Q2":"Govorilo se talijanksi","Q3":"hrvatski i talijanski","Q4":"u Hrvatskoj","Q5":"Govorim više jezika i moram ih sve prakticirati jer inače nalazim poteškoće u govoru"}, survey-text                                                                                                                                                                                                                , 32                                                                                                                                                                                                                         , 693809                                                                                                                                                                                                                     , 0.0-3.0
# 17 161529.054999999                                                                                                                                                                                                                                                                                  , {"Q0":"jeste","Q1":"","Q2":"1. da\\n2. ne","Q3":"1. da\\n2. ne","Q4":"Banja Luka, Bosna i Hercegovina","Q5":"Veza između prisvojne zamjenice (moj, moja, moje) i imenice u uvodnim rečenicama Vašeg eksperimenta mi je pomogla da odredim rod imenice i tako ga (pravilno) mijenjam kroz padeže."}, survey-text                                                                                                                                                                                                                                                                                       , 32                                                                                                                                                                                                                                                                                                , 503282                                                                                                                                                                                                                                                                                            , 0.0-3.0
# 18 109745.725000001                                                                                                                                                                                                                                                                          , {"Q0":"Ne","Q1":"Da, imala sam oko 12 godina.","Q2":"Ne. Več smo čitali srpske knjige.","Q3":"Ne","Q4":"Slovenia - Novo mesto","Q5":"Srpski jezik naučila sam zbog srpskih pjevača. Jer volim, da slušam ovo muziku i slušam pjevače kad govore o svom životu. I volim srpske youtubere."}, survey-text                                                                                                                                                                                                                                                                               , 32                                                                                                                                                                                                                                                                                        , 333912                                                                                                                                                                                                                                                                                    , 0.0-3.0
# 19 72130.5750000011                                                                                          , {"Q0":"NE.","Q1":"10","Q2":"ne, slovenački","Q3":"ne, slovenački","Q4":"U Sloveniji, u Mariboru.","Q5":""}, survey-text                                                                                               , 32                                                                                                        , 293743                                                                                                    , 0.0-3.0
# 20 57651.3999999734                                   , {"Q0":"Ne","Q1":"","Q2":"","Q3":"","Q4":"","Q5":""}, survey-text                                        , 32                                                 , 381466                                             , 0.0-3.0
